# %% [markdown]
# # FIFA Pipeline implementation RUN

# %% [markdown]
# In this notebook we implement a more rigorous pipeline approach.<br>
# As much as possible should be done with scikit-learn.

# %%
# %run 4_pipeline_functions.ipynb
# %run 5_pipeline_clean.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2000 non-null   int64
#  1   Name                      2000 non-null   object
#  2   Age                       2000 non-null   int64
#  3   Nationality               2000 non-null   object
#  4   Overall                   2000 non-null   int64
#  5   Club                      1969 non-null   object
#  6   Value                     2000 non-null   object
#  7   Wage                      2000 non-null   object
#  8   Preferred Foot            1997 non-null   object
#  9   International Reputation  1997 non-null   float64
#  10  Weak Foot                 1997 non-null   float64
#  11  Skill Moves               1997 non-null   float64
#  12  Work Rate                 1997 non-null   object
#  13  Body Type                 1997 non-null   object
#  14  Position                  1997 non-null   object
#  15  Jersey Number             1997 non-null   float64
#  16  Joined                    1833 non-null   object
#  17  Loaned From               133 non-null    object
#  18  Contract Valid Until      1966 non-null   object
#  19  Height                    1997 non-null   object
#  20  Weight                    1997 non-null   object
#  21  Finishing                 1997 non-null   float64
#  22  HeadingAccuracy           1997 non-null   float64
#  23  Dribbling                 1997 non-null   float64
#  24  Reactions                 1997 non-null   float64
#  25  Vision                    1997 non-null   float64
#  26  Release Clause            1830 non-null   object
# dtypes: float64(9), int64(3), object(15)
# memory usage: 422.0+ KB

# %% [markdown]
# ## Start building the pipeline

# %% [markdown]
# Perform CV on the train set and keep a hold-out set

# %%
X = df.drop('Value', axis = 1)
y = df['Value']

# %%
test_scores = {} # Save all the test scores for comparison.
best_CV_scores = {} # Save all the best CV scores for comparison.

# %% [markdown]
# #### DummyRegressor (naive)
# Perform a naive regressor (see if our models perform better)

# %%
print('Mean:', format(np.mean(df.Value), 'E'))
print('Median:', format(np.median(df.Value), 'E'))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

strategies = ['mean', 'median']

for strategy in strategies:
    dummy_reg = DummyRegressor(strategy = strategy)
    
    dummy_reg.fit(X_train, y_train)
    
    y_pred = dummy_reg.predict(X_test)
    
    print('Strategy:', strategy, '### Score:', format(np.sqrt(mean_squared_error(y_test, y_pred)), 'E'))
# Out:
# Mean: 2.403422E+06
# Median: 6.750000E+05
# Strategy: mean ### Score: 4.773063E+06
# Strategy: median ### Score: 5.062146E+06

# %% [markdown]
# ## Main run

# %%
#n_iters = [10 ** 2, 10 ** 3]
n_iters = [10 ** 2, 10 ** 3, 10 ** 4]

# %% [markdown]
# ### Numerical features

# %%
set_features = 'num_features'

X_train, X_test, y_train, y_test = get_train_test_sets(X, set_features)

col_trans = build_col_trans(set_features)

steps = [('col_trans', col_trans),
         ('scaler', None),
         ('model', None)]

pipeline = Pipeline(steps)

ttr = TransformedTargetRegressor(regressor = pipeline, transformer = None)

for n_iter in n_iters:
    # %run 6_pipeline_num.ipynb
# Out:
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform'), 'regressor__model__n_neighbors': 3, 'regressor__model__weights': 'uniform', 'regressor__scaler': None, 'transformer': None}
# Best CV score: 1.017913E+06
# Test score: 9.709342E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': None, 'regressor__model__weights': 'uniform', 'regressor__model__n_neighbors': 3, 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform'), 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 1.020963E+06
# Test score: 9.916254E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.144406E+06
# Test score: 9.676021E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': False, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.144406E+06
# Test score: 9.676021E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.95,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__l1_ratio': 0.95, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.144477E+06
# Test score: 9.676150E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': True, 'regressor__model__l1_ratio': 0.5, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.5,
#            max_iter=1000000, normalize=True, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.145237E+06
# Test score: 9.682017E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__model__n_estimators': 90, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__bootstrap': True, 'regressor__model': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=10, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=90, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 1.040678E+06
# Test score: 8.017729E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__scaler': None, 'regressor__model__n_estimators': 60, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__bootstrap': False, 'regressor__model': ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=10, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=8, min_weight_fraction_leaf=0.0,
#                     n_estimators=60, n_jobs=None, oob_score=False,
#                     random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 9.330749E+05
# Test score: 8.254779E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__model__n_estimators': 30, 'regressor__model__loss': 'linear', 'regressor__model__learning_rate': 0.05, 'regressor__model': AdaBoostRegressor(base_estimator=None, learning_rate=0.05, loss='linear',
#                   n_estimators=30, random_state=1), 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 1.379563E+06
# Test score: 1.193208E+06
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__n_estimators': 90, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 3, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__loss': 'lad', 'regressor__model__learning_rate': 0.1, 'regressor__model': GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='lad',
#                           max_depth=10, max_features='auto',
#                           max_leaf_nodes=None, min_impurity_decrease=0.0,
#                           min_impurity_split=None, min_samples_leaf=3,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=90, n_iter_no_change=None,
#                           presort='deprecated', random_state=1, subsample=1.0,
#                           tol=0.0001, validation_fraction=0.1, verbose=0,
#                           warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 1.118331E+06
# Test score: 8.846254E+05
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__scaler': None, 'regressor__model__subsample': 1, 'regressor__model__n_estimators': 70, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 5, 'regressor__model__max_features': 'sqrt', 'regressor__model__max_depth': 5, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model__lambda': 100, 'regressor__model__colsample_bytree': 1, 'regressor__model__alpha': 1, 'regressor__model': XGBRegressor(alpha=1, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', lambda=100, learning_rate=0.1, loss='ls',
#              max_delta_step=0, max_depth=5, max_features='sqrt',
#              min_child_weight=1, min_samples_leaf=5, min_samples_split=2,
#              missing=nan, n_estimators=70, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=1, verbosity=1), 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent'}
# Best CV score: 1.006553E+06
# Test score: 8.246987E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform'), 'regressor__model__n_neighbors': 3, 'regressor__model__weights': 'uniform', 'regressor__scaler': None, 'transformer': None}
# Best CV score: 1.017913E+06
# Test score: 9.709342E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': None, 'regressor__model__weights': 'uniform', 'regressor__model__n_neighbors': 3, 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform'), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.017913E+06
# Test score: 9.709342E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.144406E+06
# Test score: 9.676021E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': False, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.144406E+06
# Test score: 9.676021E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.95,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__l1_ratio': 0.95, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.144477E+06
# Test score: 9.676150E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': True, 'regressor__model__l1_ratio': 0.5, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.5,
#            max_iter=1000000, normalize=True, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.145237E+06
# Test score: 9.682017E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__n_estimators': 90, 'regressor__model__min_samples_split': 4, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__bootstrap': True, 'regressor__model': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=10, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=4, min_weight_fraction_leaf=0.0,
#                       n_estimators=90, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 1.015466E+06
# Test score: 8.140415E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__model__n_estimators': 70, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': None, 'regressor__model__bootstrap': False, 'regressor__model': ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=8, min_weight_fraction_leaf=0.0,
#                     n_estimators=70, n_jobs=None, oob_score=False,
#                     random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 9.177816E+05
# Test score: 8.066655E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': None, 'regressor__model__n_estimators': 60, 'regressor__model__loss': 'exponential', 'regressor__model__learning_rate': 0.05, 'regressor__model': AdaBoostRegressor(base_estimator=None, learning_rate=0.05, loss='exponential',
#                   n_estimators=60, random_state=1), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.314724E+06
# Test score: 1.036569E+06
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__scaler': None, 'regressor__model__n_estimators': 50, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 5, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model': GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=5,
#                           max_features='auto', max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=8,
#                           min_weight_fraction_leaf=0.0, n_estimators=50,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=1, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 9.723513E+05
# Test score: 8.964058E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__subsample': 0.5, 'regressor__model__n_estimators': 60, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 5, 'regressor__model__max_features': 'sqrt', 'regressor__model__max_depth': 5, 'regressor__model__loss': 'lad', 'regressor__model__learning_rate': 0.1, 'regressor__model__lambda': 10, 'regressor__model__colsample_bytree': 1, 'regressor__model__alpha': 1, 'regressor__model': XGBRegressor(alpha=1, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', lambda=10, learning_rate=0.1, loss='lad',
#              max_delta_step=0, max_depth=5, max_features='sqrt',
#              min_child_weight=1, min_samples_leaf=5, min_samples_split=2,
#              missing=nan, n_estimators=60, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=0.5, verbosity=1), 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 9.936802E+05
# Test score: 8.536823E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform'), 'regressor__model__n_neighbors': 3, 'regressor__model__weights': 'uniform', 'regressor__scaler': None, 'transformer': None}
# Best CV score: 1.017913E+06
# Test score: 9.709342E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': None, 'regressor__model__weights': 'uniform', 'regressor__model__n_neighbors': 3, 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform'), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.017913E+06
# Test score: 9.709342E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.144406E+06
# Test score: 9.676021E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': False, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.144406E+06
# Test score: 9.676021E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.95,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__l1_ratio': 0.95, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.144477E+06
# Test score: 9.676150E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': False, 'regressor__model__l1_ratio': 0.95, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.95,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.144477E+06
# Test score: 9.676150E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__n_estimators': 100, 'regressor__model__min_samples_split': 4, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__bootstrap': True, 'regressor__model': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=10, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=4, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 1.012160E+06
# Test score: 8.182351E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': None, 'regressor__model__n_estimators': 90, 'regressor__model__min_samples_split': 4, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__bootstrap': False, 'regressor__model': ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=10, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=4, min_weight_fraction_leaf=0.0,
#                     n_estimators=90, n_jobs=None, oob_score=False,
#                     random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 9.008635E+05
# Test score: 8.269080E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__scaler': None, 'regressor__model__n_estimators': 40, 'regressor__model__loss': 'linear', 'regressor__model__learning_rate': 0.05, 'regressor__model': AdaBoostRegressor(base_estimator=None, learning_rate=0.05, loss='linear',
#                   n_estimators=40, random_state=1), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.300116E+06
# Test score: 1.060386E+06
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__scaler': None, 'regressor__model__n_estimators': 50, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 5, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model': GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=5,
#                           max_features='auto', max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=8,
#                           min_weight_fraction_leaf=0.0, n_estimators=50,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=1, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False), 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 9.723513E+05
# Test score: 8.964058E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__subsample': 0.7, 'regressor__model__n_estimators': 50, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 2, 'regressor__model__max_depth': 5, 'regressor__model__loss': 'quantile', 'regressor__model__learning_rate': 0.1, 'regressor__model__lambda': 0, 'regressor__model__colsample_bytree': 1, 'regressor__model__alpha': 10, 'regressor__model': XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', lambda=0, learning_rate=0.1,
#              loss='quantile', max_delta_step=0, max_depth=5, max_features=2,
#              min_child_weight=1, min_samples_leaf=1, min_samples_split=8,
#              missing=nan, n_estimators=50, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=0.7, verbosity=1), 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 9.381215E+05
# Test score: 7.988340E+05
# #################################################################################################

# %% [markdown]
# ### Numerical + ordinal features

# %%
set_features = 'num_ord_features'

X_train, X_test, y_train, y_test = get_train_test_sets(X, set_features)

col_trans = build_col_trans(set_features)

steps = [('col_trans', col_trans),
         ('scaler', None),         
        ('model', None)]

pipeline = Pipeline(steps)

ttr = TransformedTargetRegressor(regressor = pipeline, transformer = None)

for n_iter in n_iters:
    # %run 7_pipeline_num_ord.ipynb
# Out:
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='distance'), 'regressor__model__n_neighbors': 2, 'regressor__model__weights': 'distance', 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': None}
# Best CV score: 9.897204E+05
# Test score: 1.117380E+06
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__weights': 'distance', 'regressor__model__n_neighbors': 2, 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='distance'), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 9.897809E+05
# Test score: 1.117356E+06
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123459E+06
# Test score: 9.524248E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': False, 'regressor__model__fit_intercept': True, 'regressor__model__alpha': 100.0, 'regressor__model': Ridge(alpha=100.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.128358E+06
# Test score: 9.420533E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.75,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__l1_ratio': 0.75, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.122893E+06
# Test score: 9.549142E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': False, 'regressor__model__l1_ratio': 0.25, 'regressor__model__fit_intercept': True, 'regressor__model__alpha': 0.1, 'regressor__model': ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.25,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.128176E+06
# Test score: 9.398199E+05
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__n_estimators': 30, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 100, 'regressor__model__bootstrap': True, 'regressor__model': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=100, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=30, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent'}
# Best CV score: 7.575617E+05
# Test score: 4.329406E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__n_estimators': 80, 'regressor__model__min_samples_split': 4, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 100, 'regressor__model__bootstrap': False, 'regressor__model': ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=100, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=4, min_weight_fraction_leaf=0.0,
#                     n_estimators=80, n_jobs=None, oob_score=False,
#                     random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 6.841812E+05
# Test score: 5.551185E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__model__n_estimators': 90, 'regressor__model__loss': 'square', 'regressor__model__learning_rate': 0.05, 'regressor__model': AdaBoostRegressor(base_estimator=None, learning_rate=0.05, loss='square',
#                   n_estimators=90, random_state=1), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 1.109987E+06
# Test score: 1.082223E+06
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__model__n_estimators': 100, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 3, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model': GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=10,
#                           max_features='auto', max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=3, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=1, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 7.860571E+05
# Test score: 4.663255E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__model__subsample': 0.9, 'regressor__model__n_estimators': 80, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 3, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__loss': 'lad', 'regressor__model__learning_rate': 0.1, 'regressor__model__lambda': 1, 'regressor__model__colsample_bytree': 1, 'regressor__model__alpha': 10, 'regressor__model': XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', lambda=1, learning_rate=0.1, loss='lad',
#              max_delta_step=0, max_depth=10, max_features='auto',
#              min_child_weight=1, min_samples_leaf=3, min_samples_split=2,
#              missing=nan, n_estimators=80, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=0.9, verbosity=1), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 6.228664E+05
# Test score: 4.375737E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='distance'), 'regressor__model__n_neighbors': 2, 'regressor__model__weights': 'distance', 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': None}
# Best CV score: 9.897204E+05
# Test score: 1.117380E+06
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__weights': 'distance', 'regressor__model__n_neighbors': 2, 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='distance'), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 9.897204E+05
# Test score: 1.117380E+06
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123459E+06
# Test score: 9.524248E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': True, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=True, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.123459E+06
# Test score: 9.524248E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.75,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__l1_ratio': 0.75, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.122893E+06
# Test score: 9.549142E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': False, 'regressor__model__l1_ratio': 0.5, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.5,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.123184E+06
# Test score: 9.568610E+05
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__n_estimators': 90, 'regressor__model__min_samples_split': 4, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 100, 'regressor__model__bootstrap': True, 'regressor__model': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=100, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=4, min_weight_fraction_leaf=0.0,
#                       n_estimators=90, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent'}
# Best CV score: 7.467978E+05
# Test score: 4.357663E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__n_estimators': 70, 'regressor__model__min_samples_split': 4, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 50, 'regressor__model__bootstrap': False, 'regressor__model': ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=50, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=4, min_weight_fraction_leaf=0.0,
#                     n_estimators=70, n_jobs=None, oob_score=False,
#                     random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent'}
# Best CV score: 6.415050E+05
# Test score: 4.913185E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__n_estimators': 80, 'regressor__model__loss': 'exponential', 'regressor__model__learning_rate': 0.1, 'regressor__model': AdaBoostRegressor(base_estimator=None, learning_rate=0.1, loss='exponential',
#                   n_estimators=80, random_state=1), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent'}
# Best CV score: 1.083923E+06
# Test score: 9.950124E+05
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__n_estimators': 70, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model': GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=10,
#                           max_features='auto', max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=8,
#                           min_weight_fraction_leaf=0.0, n_estimators=70,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=1, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 5.766528E+05
# Test score: 5.091527E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__subsample': 0.9, 'regressor__model__n_estimators': 90, 'regressor__model__min_samples_split': 4, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 2, 'regressor__model__max_depth': 5, 'regressor__model__loss': 'huber', 'regressor__model__learning_rate': 0.1, 'regressor__model__lambda': 0, 'regressor__model__colsample_bytree': 1, 'regressor__model__alpha': 0, 'regressor__model': XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', lambda=0, learning_rate=0.1, loss='huber',
#              max_delta_step=0, max_depth=5, max_features=2, min_child_weight=1,
#              min_samples_leaf=1, min_samples_split=4, missing=nan,
#              n_estimators=90, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=0.9, verbosity=1), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 6.220461E+05
# Test score: 4.021800E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='distance'), 'regressor__model__n_neighbors': 2, 'regressor__model__weights': 'distance', 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': None}
# Best CV score: 9.897204E+05
# Test score: 1.117380E+06
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__weights': 'distance', 'regressor__model__n_neighbors': 2, 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='distance'), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 9.897204E+05
# Test score: 1.117380E+06
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123459E+06
# Test score: 9.524248E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': False, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.123459E+06
# Test score: 9.524248E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.75,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__l1_ratio': 0.75, 'regressor__model__normalize': False, 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.122893E+06
# Test score: 9.549142E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__normalize': False, 'regressor__model__l1_ratio': 0.75, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.75,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 1.122893E+06
# Test score: 9.549142E+05
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__scaler': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__model__n_estimators': 50, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 100, 'regressor__model__bootstrap': True, 'regressor__model': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=100, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=50, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent'}
# Best CV score: 7.151929E+05
# Test score: 4.426755E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': None, 'regressor__model__n_estimators': 50, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 50, 'regressor__model__bootstrap': False, 'regressor__model': ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=50, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=50, n_jobs=None, oob_score=False,
#                     random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 6.106671E+05
# Test score: 4.969682E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__n_estimators': 80, 'regressor__model__loss': 'exponential', 'regressor__model__learning_rate': 0.1, 'regressor__model': AdaBoostRegressor(base_estimator=None, learning_rate=0.1, loss='exponential',
#                   n_estimators=80, random_state=1), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent'}
# Best CV score: 1.083923E+06
# Test score: 9.950124E+05
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__n_estimators': 100, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model': GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=10,
#                           max_features='auto', max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=8,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=1, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'median'}
# Best CV score: 5.749916E+05
# Test score: 5.093117E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__scaler': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__model__subsample': 0.7, 'regressor__model__n_estimators': 80, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 3, 'regressor__model__max_features': 2, 'regressor__model__max_depth': 10, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model__lambda': 0, 'regressor__model__colsample_bytree': 1, 'regressor__model__alpha': 1, 'regressor__model': XGBRegressor(alpha=1, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', lambda=0, learning_rate=0.1, loss='ls',
#              max_delta_step=0, max_depth=10, max_features=2, min_child_weight=1,
#              min_samples_leaf=3, min_samples_split=8, missing=nan,
#              n_estimators=80, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=0.7, verbosity=1), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'mean'}
# Best CV score: 5.989173E+05
# Test score: 4.066801E+05
# #################################################################################################

# %% [markdown]
# ### Numerical + ordinal + categorical features

# %%
set_features = 'num_ord_cat_features'

for skipPosition in [False, True]:
    if skipPosition:
        try:
            cat_features.remove('Position')
        except ValueError:
            pass

    X_train, X_test, y_train, y_test = get_train_test_sets(X, set_features)

    col_trans = ColumnTransformer([
                ('imp_num_cols', SimpleImputer(), num_features),
                ('imp_ord_cols', SimpleImputer(), ord_features),
                ('imp_cat_cols', SimpleImputer(fill_value = 'missing_value'), cat_features)
            ])

    preprocessor = ColumnTransformer([
            ('scaler_num_ord', StandardScaler(), slice(0, len(num_features + ord_features))),
            ('categoricalencoder', None, slice(len(num_features + ord_features), \
                                                          len(num_features + ord_features + cat_features)))
        ])

    steps = [('col_trans', col_trans),
             ('preprocessor', preprocessor),
             ('model', None)]

    pipeline = Pipeline(steps)

    ttr = TransformedTargetRegressor(regressor = pipeline, transformer = None)

    for n_iter in n_iters:
        # %run 8_pipeline_num_ord_cat.ipynb
# Out:
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                     weights='uniform'), 'regressor__model__n_neighbors': 1, 'regressor__model__weights': 'uniform', 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': None}
# Best CV score: 1.253525E+06
# Test score: 1.319504E+06
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__weights': 'uniform', 'regressor__model__n_neighbors': 2, 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='uniform'), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 1.061067E+06
# Test score: 1.159407E+06
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'constant', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__normalize': False, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123119E+06
# Test score: 9.535302E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__normalize': False, 'regressor__model__fit_intercept': True, 'regressor__model__alpha': 0.1, 'regressor__model': Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 1.183112E+06
# Test score: 1.018731E+06
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'constant', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.95,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__l1_ratio': 0.95, 'regressor__model__normalize': False, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123199E+06
# Test score: 9.541139E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__normalize': True, 'regressor__model__l1_ratio': 0.05, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.05,
#            max_iter=1000000, normalize=True, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 1.138185E+06
# Test score: 9.663147E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 80, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': None, 'regressor__model__bootstrap': True, 'regressor__model': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=80, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 7.968788E+05
# Test score: 4.341956E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 20, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': None, 'regressor__model__bootstrap': False, 'regressor__model': ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=20, n_jobs=None, oob_score=False,
#                     random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 7.229824E+05
# Test score: 6.635712E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 90, 'regressor__model__loss': 'square', 'regressor__model__learning_rate': 0.05, 'regressor__model': AdaBoostRegressor(base_estimator=None, learning_rate=0.05, loss='square',
#                   n_estimators=90, random_state=1), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 1.154062E+06
# Test score: 1.077877E+06
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 50, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 3, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__loss': 'quantile', 'regressor__model__learning_rate': 0.05, 'regressor__model': GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.05, loss='quantile',
#                           max_depth=10, max_features='auto',
#                           max_leaf_nodes=None, min_impurity_decrease=0.0,
#                           min_impurity_split=None, min_samples_leaf=3,
#                           min_samples_split=2, min_weight_fraction_leaf=0.0,
#                           n_estimators=50, n_iter_no_change=None,
#                           presort='deprecated', random_state=1, subsample=1.0,
#                           tol=0.0001, validation_fraction=0.1, verbose=0,
#                           warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 1.369466E+06
# Test score: 1.276127E+06
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__subsample': 0.7, 'regressor__model__n_estimators': 60, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 3, 'regressor__model__max_features': 2, 'regressor__model__max_depth': 5, 'regressor__model__loss': 'huber', 'regressor__model__learning_rate': 0.05, 'regressor__model__lambda': 10, 'regressor__model__colsample_bytree': 0.5, 'regressor__model__alpha': 0, 'regressor__model': XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.5, gamma=0,
#              importance_type='gain', lambda=10, learning_rate=0.05,
#              loss='huber', max_delta_step=0, max_depth=5, max_features=2,
#              min_child_weight=1, min_samples_leaf=3, min_samples_split=8,
#              missing=nan, n_estimators=60, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=0.7, verbosity=1), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 1.033818E+06
# Test score: 8.743520E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                     weights='uniform'), 'regressor__model__n_neighbors': 1, 'regressor__model__weights': 'uniform', 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': None}
# Best CV score: 1.253525E+06
# Test score: 1.319504E+06
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__weights': 'uniform', 'regressor__model__n_neighbors': 3, 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='uniform'), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 1.057048E+06
# Test score: 1.083603E+06
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'constant', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__normalize': False, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123119E+06
# Test score: 9.535302E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__normalize': False, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 10.0, 'regressor__model': Ridge(alpha=10.0, copy_X=True, fit_intercept=False, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 1.136098E+06
# Test score: 9.621326E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'constant', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.95,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__l1_ratio': 0.95, 'regressor__model__normalize': False, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123199E+06
# Test score: 9.541139E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__normalize': False, 'regressor__model__l1_ratio': 0.5, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.5,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 1.123749E+06
# Test score: 9.542177E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 80, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': None, 'regressor__model__bootstrap': True, 'regressor__model': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=80, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 7.968788E+05
# Test score: 4.341956E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 20, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': None, 'regressor__model__bootstrap': False, 'regressor__model': ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=20, n_jobs=None, oob_score=False,
#                     random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 7.229824E+05
# Test score: 6.635712E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 70, 'regressor__model__loss': 'linear', 'regressor__model__learning_rate': 0.1, 'regressor__model': AdaBoostRegressor(base_estimator=None, learning_rate=0.1, loss='linear',
#                   n_estimators=70, random_state=1), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 1.099299E+06
# Test score: 1.045028E+06
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 60, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 3, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 50, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model': GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=50,
#                           max_features='auto', max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=3, min_samples_split=8,
#                           min_weight_fraction_leaf=0.0, n_estimators=60,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=1, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 6.735335E+05
# Test score: 5.016070E+05
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__subsample': 0.7, 'regressor__model__n_estimators': 90, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 2, 'regressor__model__max_depth': 100, 'regressor__model__loss': 'lad', 'regressor__model__learning_rate': 0.1, 'regressor__model__lambda': 1, 'regressor__model__colsample_bytree': 1, 'regressor__model__alpha': 0, 'regressor__model': XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', lambda=1, learning_rate=0.1, loss='lad',
#              max_delta_step=0, max_depth=100, max_features=2,
#              min_child_weight=1, min_samples_leaf=1, min_samples_split=8,
#              missing=nan, n_estimators=90, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=0.7, verbosity=1), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 6.723511E+05
# Test score: 3.927704E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                     weights='uniform'), 'regressor__model__n_neighbors': 1, 'regressor__model__weights': 'uniform', 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': None}
# Best CV score: 1.253525E+06
# Test score: 1.319504E+06
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__weights': 'distance', 'regressor__model__n_neighbors': 3, 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='distance'), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 1.044439E+06
# Test score: 1.083735E+06
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'constant', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__normalize': False, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123119E+06
# Test score: 9.535302E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__normalize': True, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=True, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 1.123119E+06
# Test score: 9.535302E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'constant', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.95,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__l1_ratio': 0.95, 'regressor__model__normalize': False, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123199E+06
# Test score: 9.541139E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__normalize': False, 'regressor__model__l1_ratio': 0.75, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.75,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 1.123631E+06
# Test score: 9.527958E+05
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 40, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 100, 'regressor__model__bootstrap': True, 'regressor__model': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=100, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=40, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 7.776482E+05
# Test score: 4.615650E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 90, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 50, 'regressor__model__bootstrap': False, 'regressor__model': ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=50, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=90, n_jobs=None, oob_score=False,
#                     random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 6.453250E+05
# Test score: 5.510558E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 80, 'regressor__model__loss': 'linear', 'regressor__model__learning_rate': 0.1, 'regressor__model': AdaBoostRegressor(base_estimator=None, learning_rate=0.1, loss='linear',
#                   n_estimators=80, random_state=1), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 1.071805E+06
# Test score: 1.049023E+06
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 60, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 3, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 100, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model': GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls',
#                           max_depth=100, max_features='auto',
#                           max_leaf_nodes=None, min_impurity_decrease=0.0,
#                           min_impurity_split=None, min_samples_leaf=3,
#                           min_samples_split=8, min_weight_fraction_leaf=0.0,
#                           n_estimators=60, n_iter_no_change=None,
#                           presort='deprecated', random_state=1, subsample=1.0,
#                           tol=0.0001, validation_fraction=0.1, verbose=0,
#                           warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 6.509422E+05
# Test score: 4.678176E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__subsample': 0.9, 'regressor__model__n_estimators': 80, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model__lambda': 100, 'regressor__model__colsample_bytree': 1, 'regressor__model__alpha': 0, 'regressor__model': XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', lambda=100, learning_rate=0.1, loss='ls',
#              max_delta_step=0, max_depth=10, max_features='auto',
#              min_child_weight=1, min_samples_leaf=1, min_samples_split=2,
#              missing=nan, n_estimators=80, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=0.9, verbosity=1), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 6.180426E+05
# Test score: 4.186841E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='distance'), 'regressor__model__n_neighbors': 3, 'regressor__model__weights': 'distance', 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': None}
# Best CV score: 1.013114E+06
# Test score: 1.090847E+06
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__weights': 'uniform', 'regressor__model__n_neighbors': 2, 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                     weights='uniform'), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 1.031848E+06
# Test score: 1.144926E+06
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'constant', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__normalize': False, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123110E+06
# Test score: 9.535307E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__normalize': False, 'regressor__model__fit_intercept': True, 'regressor__model__alpha': 0.1, 'regressor__model': Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 1.154448E+06
# Test score: 1.012968E+06
# #################################################################################################
# Type of search: GS
# ...
#               handle_unknown='ignore', sparse=True), 'regressor__model__subsample': 0.7, 'regressor__model__n_estimators': 90, 'regressor__model__min_samples_split': 8, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 2, 'regressor__model__max_depth': 100, 'regressor__model__loss': 'lad', 'regressor__model__learning_rate': 0.1, 'regressor__model__lambda': 1, 'regressor__model__colsample_bytree': 1, 'regressor__model__alpha': 0, 'regressor__model': XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', lambda=1, learning_rate=0.1, loss='lad',
#              max_delta_step=0, max_depth=100, max_features=2,
#              min_child_weight=1, min_samples_leaf=1, min_samples_split=8,
#              missing=nan, n_estimators=90, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=0.7, verbosity=1), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 6.398743E+05
# Test score: 4.119046E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='distance'), 'regressor__model__n_neighbors': 3, 'regressor__model__weights': 'distance', 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'transformer': None}
# Best CV score: 1.013114E+06
# Test score: 1.090847E+06
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__weights': 'distance', 'regressor__model__n_neighbors': 3, 'regressor__model': KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                     weights='distance'), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 1.013114E+06
# Test score: 1.090847E+06
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'constant', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__normalize': False, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123110E+06
# Test score: 9.535307E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__normalize': True, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=100000,
#       normalize=True, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 1.123110E+06
# Test score: 9.535307E+05
# #################################################################################################
# Type of search: GS
# {'regressor__col_trans__imp_cat_cols__strategy': 'constant', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.95,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__model__alpha': 0.01, 'regressor__model__fit_intercept': False, 'regressor__model__l1_ratio': 0.95, 'regressor__model__normalize': False, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)}
# Best CV score: 1.123179E+06
# Test score: 9.541188E+05
# #################################################################################################
# Type of search: RS
# {'transformer': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__normalize': False, 'regressor__model__l1_ratio': 0.5, 'regressor__model__fit_intercept': False, 'regressor__model__alpha': 0.01, 'regressor__model': ElasticNet(alpha=0.01, copy_X=True, fit_intercept=False, l1_ratio=0.5,
#            max_iter=1000000, normalize=False, positive=False, precompute=False,
#            random_state=1, selection='cyclic', tol=0.0001, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'mean', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 1.123610E+06
# Test score: 9.538918E+05
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 40, 'regressor__model__min_samples_split': 4, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 100, 'regressor__model__bootstrap': True, 'regressor__model': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=100, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=4, min_weight_fraction_leaf=0.0,
#                       n_estimators=40, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 7.473235E+05
# Test score: 4.673037E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 90, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': None, 'regressor__model__bootstrap': False, 'regressor__model': ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=90, n_jobs=None, oob_score=False,
#                     random_state=1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'median', 'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 6.359289E+05
# Test score: 5.510518E+05
# #################################################################################################
# Type of search: RS
# {'transformer': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 50, 'regressor__model__loss': 'exponential', 'regressor__model__learning_rate': 0.1, 'regressor__model': AdaBoostRegressor(base_estimator=None, learning_rate=0.1, loss='exponential',
#                   n_estimators=50, random_state=1), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'median', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 1.091739E+06
# Test score: 1.000081E+06
# #################################################################################################
# Type of search: RS
# {'transformer': PowerTransformer(copy=True, method='yeo-johnson', standardize=True), 'regressor__preprocessor__scaler_num_ord': RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__n_estimators': 50, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 3, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model': GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=10,
#                           max_features='auto', max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=3, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=50,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=1, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False), 'regressor__col_trans__imp_ord_cols__strategy': 'mean', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'constant'}
# Best CV score: 6.643206E+05
# Test score: 5.322814E+05
# #################################################################################################
# Type of search: RS
# {'transformer': None, 'regressor__preprocessor__scaler_num_ord': StandardScaler(copy=True, with_mean=True, with_std=True), 'regressor__preprocessor__categoricalencoder__drop': None, 'regressor__preprocessor__categoricalencoder': OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='ignore', sparse=True), 'regressor__model__subsample': 0.9, 'regressor__model__n_estimators': 80, 'regressor__model__min_samples_split': 2, 'regressor__model__min_samples_leaf': 1, 'regressor__model__max_features': 'auto', 'regressor__model__max_depth': 10, 'regressor__model__loss': 'ls', 'regressor__model__learning_rate': 0.1, 'regressor__model__lambda': 100, 'regressor__model__colsample_bytree': 1, 'regressor__model__alpha': 0, 'regressor__model': XGBRegressor(alpha=0, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', lambda=100, learning_rate=0.1, loss='ls',
#              max_delta_step=0, max_depth=10, max_features='auto',
#              min_child_weight=1, min_samples_leaf=1, min_samples_split=2,
#              missing=nan, n_estimators=80, n_jobs=1, nthread=None,
#              objective='reg:squarederror', random_state=1, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#              subsample=0.9, verbosity=1), 'regressor__col_trans__imp_ord_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_num_cols__strategy': 'most_frequent', 'regressor__col_trans__imp_cat_cols__strategy': 'most_frequent'}
# Best CV score: 6.220467E+05
# Test score: 4.305628E+05
# #################################################################################################

# %%
print_key_value_sorted(test_scores)
# Out:
# ('xgbregressor_RS_n_iter1000_num_ord_cat_features', '3.927704E+05')
# ('xgbregressor_RS_n_iter1000_num_ord_features', '4.021800E+05')
# ('xgbregressor_RS_n_iter10000_num_ord_features', '4.066801E+05')
# ('xgbregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '4.119046E+05')
# ('xgbregressor_RS_n_iter10000_num_ord_cat_features', '4.186841E+05')
# ('xgbregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '4.305628E+05')
# ('randomforestregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '4.322234E+05')
# ('randomforestregressor_RS_n_iter100_num_ord_features', '4.329406E+05')
# ('randomforestregressor_RS_n_iter1000_num_ord_cat_features', '4.341956E+05')
# ('randomforestregressor_RS_n_iter100_num_ord_cat_features', '4.341956E+05')
# ('randomforestregressor_RS_n_iter1000_num_ord_features', '4.357663E+05')
# ('xgbregressor_RS_n_iter100_num_ord_features', '4.375737E+05')
# ('randomforestregressor_RS_n_iter10000_num_ord_features', '4.426755E+05')
# ('randomforestregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '4.453000E+05')
# ('randomforestregressor_RS_n_iter10000_num_ord_cat_features', '4.615650E+05')
# ('gradientboostingregressor_RS_n_iter100_num_ord_features', '4.663255E+05')
# ('randomforestregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '4.673037E+05')
# ('gradientboostingregressor_RS_n_iter10000_num_ord_cat_features', '4.678176E+05')
# ('gradientboostingregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '4.733064E+05')
# ('extratreesregressor_RS_n_iter1000_num_ord_features', '4.913185E+05')
# ('extratreesregressor_RS_n_iter10000_num_ord_features', '4.969682E+05')
# ('gradientboostingregressor_RS_n_iter1000_num_ord_cat_features', '5.016070E+05')
# ('gradientboostingregressor_RS_n_iter1000_num_ord_features', '5.091527E+05')
# ('gradientboostingregressor_RS_n_iter10000_num_ord_features', '5.093117E+05')
# ('gradientboostingregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '5.322814E+05')
# ('extratreesregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '5.510518E+05')
# ('extratreesregressor_RS_n_iter10000_num_ord_cat_features', '5.510558E+05')
# ('extratreesregressor_RS_n_iter100_num_ord_features', '5.551185E+05')
# ('extratreesregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '5.690472E+05')
# ('extratreesregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '5.690472E+05')
# ('extratreesregressor_RS_n_iter1000_num_ord_cat_features', '6.635712E+05')
# ('extratreesregressor_RS_n_iter100_num_ord_cat_features', '6.635712E+05')
# ('xgbregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '7.871369E+05')
# ('xgbregressor_RS_n_iter10000_num_features', '7.988340E+05')
# ('randomforestregressor_RS_n_iter100_num_features', '8.017729E+05')
# ('extratreesregressor_RS_n_iter1000_num_features', '8.066655E+05')
# ('randomforestregressor_RS_n_iter1000_num_features', '8.140415E+05')
# ('randomforestregressor_RS_n_iter10000_num_features', '8.182351E+05')
# ('xgbregressor_RS_n_iter100_num_features', '8.246987E+05')
# ('extratreesregressor_RS_n_iter100_num_features', '8.254779E+05')
# ('extratreesregressor_RS_n_iter10000_num_features', '8.269080E+05')
# ('xgbregressor_RS_n_iter1000_num_features', '8.536823E+05')
# ('xgbregressor_RS_n_iter100_num_ord_cat_features', '8.743520E+05')
# ('gradientboostingregressor_RS_n_iter100_num_features', '8.846254E+05')
# ('gradientboostingregressor_RS_n_iter10000_num_features', '8.964058E+05')
# ('gradientboostingregressor_RS_n_iter1000_num_features', '8.964058E+05')
# ('elasticnet_huberregressor_RS_n_iter100_num_ord_features', '9.398199E+05')
# ('linearregression_lasso_ridge_RS_n_iter100_num_ord_features', '9.420533E+05')
# ('linearregression_lasso_ridge_GS_num_ord_features', '9.524248E+05')
# ('linearregression_lasso_ridge_RS_n_iter10000_num_ord_features', '9.524248E+05')
# ('linearregression_lasso_ridge_RS_n_iter1000_num_ord_features', '9.524248E+05')
# ('elasticnet_huberregressor_RS_n_iter10000_num_ord_cat_features', '9.527958E+05')
# ('linearregression_lasso_ridge_GS_num_ord_cat_features', '9.535302E+05')
# ('linearregression_lasso_ridge_RS_n_iter10000_num_ord_cat_features', '9.535302E+05')
# ('linearregression_lasso_ridge_GS_num_ord_cat_features_skipPosition', '9.535307E+05')
# ('linearregression_lasso_ridge_RS_n_iter10000_num_ord_cat_features_skipPosition', '9.535307E+05')
# ('elasticnet_huberregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '9.538918E+05')
# ('elasticnet_huberregressor_GS_num_ord_cat_features', '9.541139E+05')
# ('elasticnet_huberregressor_GS_num_ord_cat_features_skipPosition', '9.541188E+05')
# ('elasticnet_huberregressor_RS_n_iter1000_num_ord_cat_features', '9.542177E+05')
# ('elasticnet_huberregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '9.543753E+05')
# ('elasticnet_huberregressor_GS_num_ord_features', '9.549142E+05')
# ('elasticnet_huberregressor_RS_n_iter10000_num_ord_features', '9.549142E+05')
# ('elasticnet_huberregressor_RS_n_iter1000_num_ord_features', '9.568610E+05')
# ('linearregression_lasso_ridge_RS_n_iter1000_num_ord_cat_features_skipPosition', '9.571450E+05')
# ('linearregression_lasso_ridge_RS_n_iter1000_num_ord_cat_features', '9.621326E+05')
# ('elasticnet_huberregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '9.653609E+05')
# ('elasticnet_huberregressor_RS_n_iter100_num_ord_cat_features', '9.663147E+05')
# ('linearregression_lasso_ridge_GS_num_features', '9.676021E+05')
# ('linearregression_lasso_ridge_RS_n_iter10000_num_features', '9.676021E+05')
# ('linearregression_lasso_ridge_RS_n_iter1000_num_features', '9.676021E+05')
# ('linearregression_lasso_ridge_RS_n_iter100_num_features', '9.676021E+05')
# ('elasticnet_huberregressor_GS_num_features', '9.676150E+05')
# ('elasticnet_huberregressor_RS_n_iter10000_num_features', '9.676150E+05')
# ('elasticnet_huberregressor_RS_n_iter1000_num_features', '9.682017E+05')
# ('elasticnet_huberregressor_RS_n_iter100_num_features', '9.682017E+05')
# ('kneighborsregressor_GS_num_features', '9.709342E+05')
# ('kneighborsregressor_RS_n_iter10000_num_features', '9.709342E+05')
# ('kneighborsregressor_RS_n_iter1000_num_features', '9.709342E+05')
# ('adaboostregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '9.870224E+05')
# ('kneighborsregressor_RS_n_iter100_num_features', '9.916254E+05')
# ('adaboostregressor_RS_n_iter10000_num_ord_features', '9.950124E+05')
# ('adaboostregressor_RS_n_iter1000_num_ord_features', '9.950124E+05')
# ('adaboostregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '1.000081E+06')
# ('linearregression_lasso_ridge_RS_n_iter100_num_ord_cat_features_skipPosition', '1.012968E+06')
# ('linearregression_lasso_ridge_RS_n_iter100_num_ord_cat_features', '1.018731E+06')
# ('adaboostregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '1.030121E+06')
# ('adaboostregressor_RS_n_iter1000_num_features', '1.036569E+06')
# ('adaboostregressor_RS_n_iter1000_num_ord_cat_features', '1.045028E+06')
# ('adaboostregressor_RS_n_iter10000_num_ord_cat_features', '1.049023E+06')
# ('adaboostregressor_RS_n_iter10000_num_features', '1.060386E+06')
# ('adaboostregressor_RS_n_iter100_num_ord_cat_features', '1.077877E+06')
# ('adaboostregressor_RS_n_iter100_num_ord_features', '1.082223E+06')
# ('kneighborsregressor_RS_n_iter1000_num_ord_cat_features', '1.083603E+06')
# ('kneighborsregressor_RS_n_iter10000_num_ord_cat_features', '1.083735E+06')
# ('kneighborsregressor_GS_num_ord_cat_features_skipPosition', '1.090847E+06')
# ('kneighborsregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '1.090847E+06')
# ('kneighborsregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '1.091499E+06')
# ('kneighborsregressor_RS_n_iter100_num_ord_features', '1.117356E+06')
# ('kneighborsregressor_GS_num_ord_features', '1.117380E+06')
# ('kneighborsregressor_RS_n_iter10000_num_ord_features', '1.117380E+06')
# ('kneighborsregressor_RS_n_iter1000_num_ord_features', '1.117380E+06')
# ('kneighborsregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '1.144926E+06')
# ('kneighborsregressor_RS_n_iter100_num_ord_cat_features', '1.159407E+06')
# ('adaboostregressor_RS_n_iter100_num_features', '1.193208E+06')
# ('gradientboostingregressor_RS_n_iter100_num_ord_cat_features', '1.276127E+06')
# ('gradientboostingregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '1.298944E+06')
# ('kneighborsregressor_GS_num_ord_cat_features', '1.319504E+06')

# %%
print_key_value_sorted(best_CV_scores)
# Out:
# ('gradientboostingregressor_RS_n_iter10000_num_ord_features', '5.749916E+05')
# ('gradientboostingregressor_RS_n_iter1000_num_ord_features', '5.766528E+05')
# ('xgbregressor_RS_n_iter10000_num_ord_features', '5.989173E+05')
# ('extratreesregressor_RS_n_iter10000_num_ord_features', '6.106671E+05')
# ('xgbregressor_RS_n_iter10000_num_ord_cat_features', '6.180426E+05')
# ('xgbregressor_RS_n_iter1000_num_ord_features', '6.220461E+05')
# ('xgbregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '6.220467E+05')
# ('xgbregressor_RS_n_iter100_num_ord_features', '6.228664E+05')
# ('extratreesregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '6.359289E+05')
# ('xgbregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '6.398743E+05')
# ('extratreesregressor_RS_n_iter1000_num_ord_features', '6.415050E+05')
# ('extratreesregressor_RS_n_iter10000_num_ord_cat_features', '6.453250E+05')
# ('gradientboostingregressor_RS_n_iter10000_num_ord_cat_features', '6.509422E+05')
# ('gradientboostingregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '6.643206E+05')
# ('gradientboostingregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '6.660205E+05')
# ('xgbregressor_RS_n_iter1000_num_ord_cat_features', '6.723511E+05')
# ('gradientboostingregressor_RS_n_iter1000_num_ord_cat_features', '6.735335E+05')
# ('extratreesregressor_RS_n_iter100_num_ord_features', '6.841812E+05')
# ('extratreesregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '7.088576E+05')
# ('extratreesregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '7.088576E+05')
# ('randomforestregressor_RS_n_iter10000_num_ord_features', '7.151929E+05')
# ('extratreesregressor_RS_n_iter1000_num_ord_cat_features', '7.229824E+05')
# ('extratreesregressor_RS_n_iter100_num_ord_cat_features', '7.229824E+05')
# ('randomforestregressor_RS_n_iter1000_num_ord_features', '7.467978E+05')
# ('randomforestregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '7.473235E+05')
# ('randomforestregressor_RS_n_iter100_num_ord_features', '7.575617E+05')
# ('randomforestregressor_RS_n_iter10000_num_ord_cat_features', '7.776482E+05')
# ('gradientboostingregressor_RS_n_iter100_num_ord_features', '7.860571E+05')
# ('randomforestregressor_RS_n_iter1000_num_ord_cat_features', '7.968788E+05')
# ('randomforestregressor_RS_n_iter100_num_ord_cat_features', '7.968788E+05')
# ('randomforestregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '8.103979E+05')
# ('randomforestregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '8.124257E+05')
# ('extratreesregressor_RS_n_iter10000_num_features', '9.008635E+05')
# ('extratreesregressor_RS_n_iter1000_num_features', '9.177816E+05')
# ('extratreesregressor_RS_n_iter100_num_features', '9.330749E+05')
# ('xgbregressor_RS_n_iter10000_num_features', '9.381215E+05')
# ('gradientboostingregressor_RS_n_iter10000_num_features', '9.723513E+05')
# ('gradientboostingregressor_RS_n_iter1000_num_features', '9.723513E+05')
# ('kneighborsregressor_GS_num_ord_features', '9.897204E+05')
# ('kneighborsregressor_RS_n_iter10000_num_ord_features', '9.897204E+05')
# ('kneighborsregressor_RS_n_iter1000_num_ord_features', '9.897204E+05')
# ('kneighborsregressor_RS_n_iter100_num_ord_features', '9.897809E+05')
# ('xgbregressor_RS_n_iter1000_num_features', '9.936802E+05')
# ('xgbregressor_RS_n_iter100_num_features', '1.006553E+06')
# ('randomforestregressor_RS_n_iter10000_num_features', '1.012160E+06')
# ('kneighborsregressor_GS_num_ord_cat_features_skipPosition', '1.013114E+06')
# ('kneighborsregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '1.013114E+06')
# ('randomforestregressor_RS_n_iter1000_num_features', '1.015466E+06')
# ('kneighborsregressor_GS_num_features', '1.017913E+06')
# ('kneighborsregressor_RS_n_iter10000_num_features', '1.017913E+06')
# ('kneighborsregressor_RS_n_iter1000_num_features', '1.017913E+06')
# ('kneighborsregressor_RS_n_iter100_num_features', '1.020963E+06')
# ('kneighborsregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '1.026478E+06')
# ('kneighborsregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '1.031848E+06')
# ('xgbregressor_RS_n_iter100_num_ord_cat_features', '1.033818E+06')
# ('randomforestregressor_RS_n_iter100_num_features', '1.040678E+06')
# ('kneighborsregressor_RS_n_iter10000_num_ord_cat_features', '1.044439E+06')
# ('kneighborsregressor_RS_n_iter1000_num_ord_cat_features', '1.057048E+06')
# ('kneighborsregressor_RS_n_iter100_num_ord_cat_features', '1.061067E+06')
# ('adaboostregressor_RS_n_iter10000_num_ord_cat_features', '1.071805E+06')
# ('xgbregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '1.082723E+06')
# ('adaboostregressor_RS_n_iter10000_num_ord_features', '1.083923E+06')
# ('adaboostregressor_RS_n_iter1000_num_ord_features', '1.083923E+06')
# ('adaboostregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '1.091739E+06')
# ('adaboostregressor_RS_n_iter1000_num_ord_cat_features', '1.099299E+06')
# ('adaboostregressor_RS_n_iter100_num_ord_features', '1.109987E+06')
# ('adaboostregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '1.114877E+06')
# ('gradientboostingregressor_RS_n_iter100_num_features', '1.118331E+06')
# ('elasticnet_huberregressor_GS_num_ord_features', '1.122893E+06')
# ('elasticnet_huberregressor_RS_n_iter10000_num_ord_features', '1.122893E+06')
# ('linearregression_lasso_ridge_GS_num_ord_cat_features_skipPosition', '1.123110E+06')
# ('linearregression_lasso_ridge_RS_n_iter10000_num_ord_cat_features_skipPosition', '1.123110E+06')
# ('linearregression_lasso_ridge_GS_num_ord_cat_features', '1.123119E+06')
# ('linearregression_lasso_ridge_RS_n_iter10000_num_ord_cat_features', '1.123119E+06')
# ('elasticnet_huberregressor_GS_num_ord_cat_features_skipPosition', '1.123179E+06')
# ('elasticnet_huberregressor_RS_n_iter1000_num_ord_features', '1.123184E+06')
# ('elasticnet_huberregressor_GS_num_ord_cat_features', '1.123199E+06')
# ('linearregression_lasso_ridge_GS_num_ord_features', '1.123459E+06')
# ('linearregression_lasso_ridge_RS_n_iter10000_num_ord_features', '1.123459E+06')
# ('linearregression_lasso_ridge_RS_n_iter1000_num_ord_features', '1.123459E+06')
# ('elasticnet_huberregressor_RS_n_iter1000_num_ord_cat_features_skipPosition', '1.123571E+06')
# ('elasticnet_huberregressor_RS_n_iter10000_num_ord_cat_features_skipPosition', '1.123610E+06')
# ('elasticnet_huberregressor_RS_n_iter10000_num_ord_cat_features', '1.123631E+06')
# ('elasticnet_huberregressor_RS_n_iter1000_num_ord_cat_features', '1.123749E+06')
# ('linearregression_lasso_ridge_RS_n_iter1000_num_ord_cat_features_skipPosition', '1.126796E+06')
# ('elasticnet_huberregressor_RS_n_iter100_num_ord_features', '1.128176E+06')
# ('linearregression_lasso_ridge_RS_n_iter100_num_ord_features', '1.128358E+06')
# ('elasticnet_huberregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '1.130501E+06')
# ('linearregression_lasso_ridge_RS_n_iter1000_num_ord_cat_features', '1.136098E+06')
# ('elasticnet_huberregressor_RS_n_iter100_num_ord_cat_features', '1.138185E+06')
# ('linearregression_lasso_ridge_GS_num_features', '1.144406E+06')
# ('linearregression_lasso_ridge_RS_n_iter10000_num_features', '1.144406E+06')
# ('linearregression_lasso_ridge_RS_n_iter1000_num_features', '1.144406E+06')
# ('linearregression_lasso_ridge_RS_n_iter100_num_features', '1.144406E+06')
# ('elasticnet_huberregressor_GS_num_features', '1.144477E+06')
# ('elasticnet_huberregressor_RS_n_iter10000_num_features', '1.144477E+06')
# ('elasticnet_huberregressor_RS_n_iter1000_num_features', '1.145237E+06')
# ('elasticnet_huberregressor_RS_n_iter100_num_features', '1.145237E+06')
# ('adaboostregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '1.147431E+06')
# ('adaboostregressor_RS_n_iter100_num_ord_cat_features', '1.154062E+06')
# ('linearregression_lasso_ridge_RS_n_iter100_num_ord_cat_features_skipPosition', '1.154448E+06')
# ('linearregression_lasso_ridge_RS_n_iter100_num_ord_cat_features', '1.183112E+06')
# ('kneighborsregressor_GS_num_ord_cat_features', '1.253525E+06')
# ('adaboostregressor_RS_n_iter10000_num_features', '1.300116E+06')
# ('adaboostregressor_RS_n_iter1000_num_features', '1.314724E+06')
# ('gradientboostingregressor_RS_n_iter100_num_ord_cat_features', '1.369466E+06')
# ('adaboostregressor_RS_n_iter100_num_features', '1.379563E+06')
# ('gradientboostingregressor_RS_n_iter100_num_ord_cat_features_skipPosition', '1.393019E+06')
